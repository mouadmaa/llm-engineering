# %%
from core.ollama_client import chat_with_ollama
from scraper import fetch_website_contents
from IPython.display import Markdown

# %%
messages = [
    {
        "role": "user",
        "content": "Tell me a fun fact"
    }
]
# messages = [
#     {
#         "role": "system",
#         "content": "You are a helpful assistant"
#     },
#     {
#         "role": "user",
#         "content": "What is 2 * 3"
#     }
# ]

reply = chat_with_ollama(
    messages=messages,
)

print(reply)
# Out:
# Here's one:
#
# **There is a species of jellyfish that is immortal!**
#
# The Turritopsis dohrnii, also known as the "immortal jellyfish," is a type of jellyfish that can transform its body into a younger state through a process called transdifferentiation. This means that it can essentially revert back to its polyp stage and then grow back into an adult again, making it theoretically immortal!
#
# Isn't that cool?

# %%
ed = fetch_website_contents("https://edwarddonner.com")
print(ed)

# %%
system_prompt = """
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be like navigation related or other irrelevant text.
Respond in markdown and translate to Arabic language. Do not wrap the markdown in a code block - respond just with the markdown.
"""

user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

def summarize(url):
    website = fetch_website_contents(url)
    response = chat_with_ollama(
        messages=messages_for(website),
        timeout=600
    )
    return response

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

display_summary("https://edwarddonner.com")
# Out:
# # هذا موقع ويب يحمل عنوان "إدورد دونر"
# هو معلم للتكنولوجيا الصناعية العليا، وقد وضع خارطات لطلاب العلم. يلخص للموقع:
# - أن Ed من مؤسسي Nebula.io، وهو شركة تقوم بترميز الذكاء عند الناس والتفاعل بين الخدماء والمجتمع.
# - يمكن أن يشرح لكم تفاصيل أكثر عن الموضوعين.
#
# # أحداث على الموقع
# * في عام 2025: طرح مواضيع مختلفة حول التطوير في العمل مع الذكاء الصناعي، منهم:
#  * كيفية إضافته إلى مشاريع العمل الخاصة بهم.
#  * كيفية عمل الخواص والتشغيل على البوتات والتقنيات الآلية.
# * أنشأ برامج إلكترونية لمحترفين ذو خبرة قصيرة في هذا المجال، مع توجيه الأهداف بشكل يسمح بالإدخار.
# * إنها محاولة لاستخدام التكنولوجيا المضبوطة والسيطرة على الوظائف المتقدمة التي تم تحريرها سابقًا.
