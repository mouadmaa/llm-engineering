# %%
from core.ollama_client import chat_with_ollama

messages = [
    {"role": "user", "content": "Hello, This is my first ever message to you! Hi!"}
]

reply = chat_with_ollama(
    messages=messages,
)

print(reply)
# Out:
# Welcome to our conversation! It's great to meet you. Don't worry if it's your first time here - I'm happy to chat with you and help with anything that's on your mind.
#
# How's your day going so far? What would you like to talk about or ask me? I'm all ears (or rather, all text)!
