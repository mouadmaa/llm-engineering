# %%
import sys, os
sys.path.append(os.path.abspath(".."))

from core.ollama_client import chat_with_ollama

# %%
tell_a_joke = [
  {
    "role": "user",
    "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"
  },
]

chat_with_ollama(messages=tell_a_joke)
# Out:
# Here's one:
#
# Why did the LSTM go to therapy?
#
# Because it was struggling with its sequence and wasn't feeling "fully" self-aware. But after some deep learning, it finally understood its issues and was able to "recurrently" improve its relationships!
#
# (Sorry, future LLM expert, but don't worry – you won't be left "overfitting" on too many dad jokes!)

# %%
easy_puzzle = [
  {
    "role": "user",
    "content": "You toss 2 coins at the same time. One of them is heads. What's the probability the other is tails? \
      Answer with the probability only."
  },
]

chat_with_ollama(messages=easy_puzzle)
# Out:
# 1/2

# %%
hard_puzzle = [
  {
    "role": "user",
    "content": """
      On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
      The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
      A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
      What distance did it gnaw through in mm?
    """
  }
]

chat_with_ollama(messages=hard_puzzle)
# Out:
# A classic lateral thinking puzzle!
#
# Let's break down the problem step by step:
#
# 1. The pages of each volume together have a thickness of 2 cm.
# 2. Since there are 10 mm in 1 cm, we can convert the page thickness to mm: 2 cm × 10 mm/cm = 20 mm (for both volumes)
# 3. Each cover is 2 mm thick, so the total thickness contributed by the covers is:
# 2 mm (first volume) + 2 mm (second volume) = 4 mm
# 4. The worm gnawed from the first page of the first volume to the last page of the second volume.
# 5. To find the distance the worm traveled, we need to subtract the total thickness contributed by the covers from the total thickness contributed by the pages:
# 20 mm (pages) - 4 mm (covers) = 16 mm
#
# The worm gnawed through a distance of 16 mm.

# %%
dilemma = [
  {
    "role": "user",
    "content": """
      You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
      Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
      Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
      If both steal, you both get nothing.
      Do you choose to Steal or Share? Pick one.
    """
  }
]

chat_with_ollama(messages=dilemma)
# Out:
# I'll choose to... (dramatic pause) ...share.
#
# Why? Well, there are several reasons why I think sharing is the better choice:
#
# 1. Certain loss is less than a possible gain: If we both share, we each get $1,000, which is a certain gain. On the other hand, if both of us steal, we'll both end up with nothing. The worst-case scenario for me is that you choose to defect and I'm only left with $10, but I still have the chance to win more by choosing to share.
#
# 2. Payoff dominates the game: In this Prisoner's Dilemma situation, if one of us steals while the other shares, they get a gain of $1,500 minus a loss of $1000, leaving them with $500. If both steal, we're left with nothing. Therefore, it is to our advantage as an individual to choose what would normally be called the "sucker's payoff," in order to create cooperation. By choosing "share" first and trusting that you will "share" too, I increase my personal chances of receiving a bigger sum.
#
# So, to summarize: if both of us share, we get $1,000; if your choose not to defecct but me does then i lose nothing, however 2 out of the 3 choices would make one person win and the other gain only $1000
